# %% [markdown]
# # Math Question Answer Verification Competition
#
# ## Starter Code

# %% [markdown]
# Borrowed from [official Unsloth implementation](https://colab.research.google.com/drive/1Ys44kVvmeZtnICzWz0xgpRnrIOjZAuxp?usp=sharing#scrollTo=MKX_XKs_BNZR)

# %%
# %%capture
# This cell will take time
# !pip install unsloth
# Also get the latest nightly Unsloth!
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Meta-Llama-3.1-8B",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# ==((====))==  Unsloth 2024.11.7: Fast Llama patching. Transformers = 4.46.2.
#    \\   /|    GPU: NVIDIA A100-SXM4-40GB. Max memory: 39.564 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.5.1+cu124. CUDA = 8.0. CUDA Toolkit = 12.4.
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/230 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/345 [00:00<?, ?B/s]

# %% [markdown]
# ## Load model and wrap with LoRA adapters

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 8, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 8,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = True,  # We support rank stabilized LoRA
    loftq_config = {
        "loftq_bits": 4,
        "loftq_iter": 2
    }, # And LoftQ
)
# Out:
# Unsloth 2024.11.7 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %% [markdown]
# ## Competition dataset

# %%
# download and load competition dataset

from datasets import load_dataset
dataset = load_dataset("ad6398/nyu-dl-teach-maths-comp")
# print and see dataset
dataset
# Out:
# README.md:   0%|          | 0.00/2.09k [00:00<?, ?B/s]
# train-00000-of-00002.parquet:   0%|          | 0.00/195M [00:00<?, ?B/s]
# train-00001-of-00002.parquet:   0%|          | 0.00/195M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/3.65M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1000000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'is_correct', 'answer', 'solution'],
#         num_rows: 1000000
#     })
#     test: Dataset({
#         features: ['question', 'is_correct', 'answer', 'solution'],
#         num_rows: 10000
#     })
# })

# %%
from datasets import Dataset

# Randomly sample 20,000 examples from the training set
sampled_indices = torch.randperm(len(dataset['train']))[:20000].tolist()
train_dataset_small = Dataset.from_dict(dataset['train'][sampled_indices])

# %%
prompt = """
You are a meticulous evaluator tasked with verifying the correctness of mathematical solutions. Your job is to analyze the given question, check the student's reasoning and the provided answer to determine if the student is correct or not.

TASK DESCRIPTION:
- Evaluate the mathematical problem and verify whether the student's final answer is correct based on the reasoning provided in their solution process.

QUESTION TYPES:
- Arithmetic: Basic operations like addition, subtraction, multiplication, and division.
- Algebra: Equations, expressions, variables, and simplification.
- Geometry: Problems involving shapes, areas, volumes, and angles.
- Calculus: Derivatives, integrals, and functions.
- Probability and Statistics: Mean, median, probabilities, and distributions.
- Logic and Word Problems: Real-world scenarios requiring logical reasoning.

SOLUTION TYPES:
- Step-by-Step Explanation: Solutions broken down into sequential steps.
- Direct Calculation: Straightforward numerical evaluation.
- Formula/Application: Usage of mathematical formulas or equations.
- Proof or Derivation: Logical proofs or derivations of results.
- Code-Based Solution: Computational solutions using programming or scripts.

1. Question: {question}
   - Analyze the question so that you have your own understanding of it.
2. Student's Answer: {answer}
3. Student's Solution Process: {solution}
   - Assess whether the solution process reflects a clear understanding of the question.
   - Check if the student has addressed all components of the question.
   - Verify that each step of the solution flows logically from the previous one.
   - Ensure no steps are skipped or assumptions are made without justification.
   - Examine calculations for precision and correctness.
   - Confirm adherence to mathematical rules and methods relevant to the problem type.
   - Evaluate if the solution process fully resolves the question, considering all requirements stated in the problem.

Output "True" if student is correct;
Output "False" if student is incorrect.

OUTPUT FORMAT:
{output}
"""

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    texts = []
    for question, answer, solution, output in zip(
        examples["question"],
        examples["answer"],
        examples["solution"],
        examples["is_correct"]
    ):
        text = prompt.format(
            question=question,
            answer=answer,
            solution=solution,
            output=output
        ) + EOS_TOKEN
        texts.append(text)
    return {"text": texts}

# %%
# Process the training dataset and generate prompt for each datapoint

# Use only 20,000 datasets for training
train_dataset = train_dataset_small.map(formatting_prompts_func, batched=True)
# Out:
# Map:   0%|          | 0/20000 [00:00<?, ? examples/s]

# %%
#print a smaple training example
train_dataset['text'][0]
# Out:
# '\nYou are a meticulous evaluator tasked with verifying the correctness of mathematical solutions. Your job is to analyze the given question, check the student\'s reasoning and the provided answer to determine if the student is correct or not.\n\nTASK DESCRIPTION:\n- Evaluate the mathematical problem and verify whether the student\'s final answer is correct based on the reasoning provided in their solution process.\n\nQUESTION TYPES:\n- Arithmetic: Basic operations like addition, subtraction, multiplication, and division.\n- Algebra: Equations, expressions, variables, and simplification.\n- Geometry: Problems involving shapes, areas, volumes, and angles.\n- Calculus: Derivatives, integrals, and functions.\n- Probability and Statistics: Mean, median, probabilities, and distributions.\n- Logic and Word Problems: Real-world scenarios requiring logical reasoning.\n\nSOLUTION TYPES:\n- Step-by-Step Explanation: Solutions broken down into sequential steps.\n- Direct Calculation: Straightforward numerical evaluation.\n- Formula/Application: Usage of mathematical formulas or equations.\n- Proof or Derivation: Logical proofs or derivations of results.\n- Code-Based Solution: Computational solutions using programming or scripts.\n\n1. Question: I want to choose a license plate which is 3 characters long, where the first character is a letter, the last character is a digit, and the middle is either a letter or a digit. I also want there to be two characters on my license plate which are the same. How many ways are there for me to choose a license plate with these restrictions?\n   - Analyze the question so that you have your own understanding of it.\n2. Student\'s Answer: M * N * O\n3. Student\'s Solution Process: Let\'s use some combinatorics to solve this.\nThe middle character can be chosen in M ways and the last digit in N ways.\nThe middle character must be the same as either the first letter or the last digit, so we have O possible choices for the middle character.\nThus, the total number of ways to choose a license plate is $M * N * O$ or \\boxed{M * N * O}.\n   - Assess whether the solution process reflects a clear understanding of the question.\n   - Check if the student has addressed all components of the question.\n   - Verify that each step of the solution flows logically from the previous one.\n   - Ensure no steps are skipped or assumptions are made without justification.\n   - Examine calculations for precision and correctness.\n   - Confirm adherence to mathematical rules and methods relevant to the problem type.\n   - Evaluate if the solution process fully resolves the question, considering all requirements stated in the problem.\n\nOutput "True" if student is correct;\nOutput "False" if student is incorrect.\n\nOUTPUT FORMAT:\nFalse\n<|end_of_text|>'

# %% [markdown]
# ## SFT

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported
from transformers import TrainerCallback

training_args = TrainingArguments(
        per_device_train_batch_size = 16,
        gradient_accumulation_steps = 8,
        warmup_ratio = 0.1, # Change to warmup ratio instead of warmup steps
        num_train_epochs = 3, # Set this for 3 full training runs.
        learning_rate = 1e-3, # Changed from 2e-4 to 1e-3
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_torch_fused",
        weight_decay = 0.05,
        lr_scheduler_type = "cosine_with_restarts", # Change from linear to cosine w/ restarts
        seed = 3407,
        output_dir = "outputs",
        eval_strategy = "steps", # Add evaluation strategy
        eval_steps = 50, # eval. every 50 steps
        save_strategy = "steps", # save the strat.
        save_steps = 50, # save every 50 steps
        load_best_model_at_end = True, # load the best model
        metric_for_best_model = "eval_loss",
        max_grad_norm = 0.3,
        report_to = "none", # Use this for WandB etc
    )

# Train test split
from sklearn.model_selection import train_test_split

train_indices, val_indices = train_test_split(
    range(len(train_dataset)),
    test_size=0.1,
    random_state=42,
    stratify=train_dataset['is_correct']  # Stratification
)

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = train_dataset.select(train_indices), # training dataset
    eval_dataset = train_dataset.select(val_indices), # evaluation dataset
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 4,
    packing = False, # Can make training 5x faster for short sequences.
    args = training_args
)

trainer_stats = trainer.train()
# Out:
# Map (num_proc=4):   0%|          | 0/18000 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/2000 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 18,000 | Num Epochs = 3
# O^O/ \_/ \    Batch size per device = 16 | Gradient Accumulation steps = 8
# \        /    Total batch size = 128 | Total steps = 420
#  "-____-"     Number of trainable parameters = 20,971,520
#     <div>
#
#       <progress value='420' max='420' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [420/420 4:15:04, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.340000</td>
#       <td>0.335591</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.315400</td>
#       <td>0.318461</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.283700</td>
#       <td>0.307107</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.281500</td>
#       <td>0.296194</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.264700</td>
#       <td>0.283892</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.217000</td>
#       <td>0.278912</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.218300</td>
#       <td>0.273583</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.208900</td>
#       <td>0.271328</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# ## Inference

# %%
# Sample inference data point
test_dataset = dataset['test']

sample_ques = test_dataset['question'][0]
sample_ans = test_dataset['answer'][0]
sample_sol = test_dataset['solution'][0]

# %%
# Running inference on single test
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
input_prompt = prompt.format(
        question=sample_ques,
        answer=sample_ans,
        solution=sample_sol,
        output=""
    )

print("Input Prompt:\n", input_prompt)
inputs = tokenizer(
[
    input_prompt
], return_tensors = "pt").to("cuda")

input_shape = inputs['input_ids'].shape
input_token_len = input_shape[1] # 1 because of batch
outputs = model.generate(**inputs,
    max_new_tokens = 64,
    min_new_tokens = 1,
    temperature = 0.1,
    do_sample = False,
    num_beams = 1,
    use_cache = True,
    pad_token_id = tokenizer.pad_token_id,
    eos_token_id = tokenizer.eos_token_id)
# you can get the whole generated text by uncommenting the below line
# text_generated = tokenizer.batch_decode([outputs, skip_special_tokens=True)

response = tokenizer.batch_decode([outputs[0][input_token_len:]], skip_special_tokens=True)
response
# Out:
# Input Prompt:
#
# You are a meticulous evaluator tasked with verifying the correctness of mathematical solutions. Your job is to analyze the given question, check the student's reasoning and the provided answer to determine if the student is correct or not.
#
# TASK DESCRIPTION:
# - Evaluate the mathematical problem and verify whether the student's final answer is correct based on the reasoning provided in their solution process.
#
# QUESTION TYPES:
# - Arithmetic: Basic operations like addition, subtraction, multiplication, and division.
# - Algebra: Equations, expressions, variables, and simplification.
# - Geometry: Problems involving shapes, areas, volumes, and angles.
# - Calculus: Derivatives, integrals, and functions.
# - Probability and Statistics: Mean, median, probabilities, and distributions.
# - Logic and Word Problems: Real-world scenarios requiring logical reasoning.
#
# SOLUTION TYPES:
# - Step-by-Step Explanation: Solutions broken down into sequential steps.
# - Direct Calculation: Straightforward numerical evaluation.
# - Formula/Application: Usage of mathematical formulas or equations.
# - Proof or Derivation: Logical proofs or derivations of results.
# - Code-Based Solution: Computational solutions using programming or scripts.
#
# 1. Question: The Parker family needs to leave the house by 5 pm for a dinner party. Mrs. Parker was waiting to get into the bathroom at 2:30 pm. Her oldest daughter used the bathroom for 45 minutes and her youngest daughter used the bathroom for another 30 minutes. Then her husband used it for 20 minutes. How much time will Mrs. Parker have to use the bathroom to leave on time?
#    - Analyze the question so that you have your own understanding of it.
# 2. Student's Answer: 205
# 3. Student's Solution Process: Let's solve this problem using Python code.
# <llm-code>
# minutes_per_hour = 60
# minutes_left_before_5 = 5 * minutes_per_hour
# total_time_spent_by_family = 45 + 30 + 20
# minutes_before_5_after_family = minutes_left_before_5 - total_time_spent_by_family
# minutes_before_5_after_family
# </llm-code>
# <llm-code-output>
# 205
# </llm-code-output>
# Thus Mrs. Parker will have \boxed{205} minutes in the bathroom before the family leaves.
#    - Assess whether the solution process reflects a clear understanding of the question.
#    - Check if the student has addressed all components of the question.
#    - Verify that each step of the solution flows logically from the previous one.
#    - Ensure no steps are skipped or assumptions are made without justification.
#    - Examine calculations for precision and correctness.
#    - Confirm adherence to mathematical rules and methods relevant to the problem type.
#    - Evaluate if the solution process fully resolves the question, considering all requirements stated in the problem.
#
# Output "True" if student is correct;
# Output "False" if student is incorrect.
#
# OUTPUT FORMAT:
# ['False\n']

# %% [markdown]
# ## Generate CSV File for Evaluation

# %%
from tqdm import tqdm

def generate_submission_file(model, tokenizer, test_dataset, prompt_template, output_file="submission.csv"):
    """
    Generate a submission file for the competition.
    """
    FastLanguageModel.for_inference(model)
    predictions = []

    print("Generating .csv file...")
    for i in tqdm(range(len(test_dataset))):
        try:
            input_prompt = prompt.format(
                question=test_dataset['question'][i],
                answer=test_dataset['answer'][i],
                solution=test_dataset['solution'][i],
                output=""
            )

            inputs = tokenizer([input_prompt], return_tensors="pt").to("cuda")
            input_token_len = inputs['input_ids'].shape[1]

            with torch.no_grad():
                outputs = model.generate(
                    **inputs,
                    max_new_tokens=1,
                    min_new_tokens=1,
                    temperature=0.1,
                    do_sample=False,
                    use_cache=True,
                    num_beams=1,
                    early_stopping=True
                )

            response = tokenizer.decode(outputs[0][input_token_len:], skip_special_tokens=True).strip().lower()
            response = response.replace("output only", "").replace("'", "").replace('"', "").strip()

            # Default to False，unless it is certainly True
            predicted_label = response == 'true'
            predictions.append(predicted_label)

        except Exception as e:
            print(f"Error asessing {i}: {str(e)}")
            # Default to False
            predictions.append(False)

    # Create dataframe
    import pandas as pd
    submission_df = pd.DataFrame({
        'ID': range(len(predictions)),
        'is_correct': predictions
    })

    # Save to .csv
    submission_df.to_csv(output_file, index=False)
    print(f"\nFile saved as {output_file}")

    # Display distribution
    value_counts = submission_df['is_correct'].value_counts()
    print("\nPrediction Distribution:")
    print(f"True: {value_counts.get(True, 0)}")
    print(f"False: {value_counts.get(False, 0)}")

    return submission_df

# Generate .csv file
submission = generate_submission_file(
    model,
    tokenizer,
    dataset['test'],
    prompt,
    "submission.csv"
)
# Out:
# Generating .csv file...
# 100%|██████████| 10000/10000 [26:48<00:00,  6.22it/s]
# File saved as submission.csv
#
# Prediction Distribution:
# True: 3361
# False: 6639

# %%
from google.colab import files

files.download('/content/submission.csv')

# %% [markdown]
# ## saving model

# %%
model.save_pretrained("lora_model") # Local saving
tokenizer.save_pretrained("lora_model")
# Out:
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/tokenizer.json')

# %%
if True:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model) # Enable native 2x faster inference
# Out:
# ==((====))==  Unsloth 2024.11.6: Fast Llama patching. Transformers = 4.46.2.
#    \\   /|    GPU: NVIDIA A100-SXM4-40GB. Max memory: 39.564 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.5.1+cu124. CUDA = 8.0. CUDA Toolkit = 12.4.
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %%
# !zip -r /content/lora_model.zip /content/lora_model/
# Out:
#   adding: content/lora_model/ (stored 0%)
#   adding: content/lora_model/tokenizer.json (deflated 85%)
#   adding: content/lora_model/README.md (deflated 66%)
#   adding: content/lora_model/tokenizer_config.json (deflated 96%)
#   adding: content/lora_model/adapter_config.json (deflated 54%)
#   adding: content/lora_model/special_tokens_map.json (deflated 71%)
#   adding: content/lora_model/adapter_model.safetensors (deflated 7%)

# %%
# !zip -r /content/outputs.zip /content/outputs/
# Out:
#   adding: content/outputs/ (stored 0%)
#   adding: content/outputs/checkpoint-700/ (stored 0%)
#   adding: content/outputs/checkpoint-700/optimizer.pt (deflated 13%)
#   adding: content/outputs/checkpoint-700/scheduler.pt (deflated 55%)
#   adding: content/outputs/checkpoint-700/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-700/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-700/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-700/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-700/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-700/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-700/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-700/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-700/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-100/ (stored 0%)
#   adding: content/outputs/checkpoint-100/optimizer.pt (deflated 11%)
#   adding: content/outputs/checkpoint-100/scheduler.pt (deflated 56%)
#   adding: content/outputs/checkpoint-100/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-100/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-100/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-100/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-100/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-100/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-100/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-100/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-100/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-150/ (stored 0%)
#   adding: content/outputs/checkpoint-150/optimizer.pt (deflated 12%)
#   adding: content/outputs/checkpoint-150/scheduler.pt (deflated 56%)
#   adding: content/outputs/checkpoint-150/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-150/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-150/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-150/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-150/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-150/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-150/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-150/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-150/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-750/ (stored 0%)
#   adding: content/outputs/checkpoint-750/optimizer.pt (deflated 13%)
#   adding: content/outputs/checkpoint-750/scheduler.pt (deflated 55%)
#   adding: content/outputs/checkpoint-750/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-750/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-750/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-750/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-750/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-750/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-750/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-750/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-750/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-250/ (stored 0%)
#   adding: content/outputs/checkpoint-250/optimizer.pt (deflated 12%)
#   adding: content/outputs/checkpoint-250/scheduler.pt (deflated 56%)
#   adding: content/outputs/checkpoint-250/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-250/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-250/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-250/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-250/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-250/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-250/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-250/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-250/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-400/ (stored 0%)
#   adding: content/outputs/checkpoint-400/optimizer.pt (deflated 12%)
#   adding: content/outputs/checkpoint-400/scheduler.pt (deflated 55%)
#   adding: content/outputs/checkpoint-400/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-400/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-400/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-400/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-400/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-400/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-400/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-400/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-400/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-300/ (stored 0%)
#   adding: content/outputs/checkpoint-300/optimizer.pt (deflated 12%)
#   adding: content/outputs/checkpoint-300/scheduler.pt (deflated 56%)
#   adding: content/outputs/checkpoint-300/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-300/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-300/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-300/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-300/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-300/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-300/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-300/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-300/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-550/ (stored 0%)
#   adding: content/outputs/checkpoint-550/optimizer.pt (deflated 12%)
#   adding: content/outputs/checkpoint-550/scheduler.pt (deflated 55%)
#   adding: content/outputs/checkpoint-550/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-550/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-550/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-550/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-550/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-550/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-550/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-550/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-550/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-850/ (stored 0%)
#   adding: content/outputs/checkpoint-850/optimizer.pt (deflated 12%)
#   adding: content/outputs/checkpoint-850/scheduler.pt (deflated 56%)
#   adding: content/outputs/checkpoint-850/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-850/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-850/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-850/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-850/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-850/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-850/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-850/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-850/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-450/ (stored 0%)
#   adding: content/outputs/checkpoint-450/optimizer.pt (deflated 12%)
#   adding: content/outputs/checkpoint-450/scheduler.pt (deflated 55%)
#   adding: content/outputs/checkpoint-450/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-450/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-450/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-450/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-450/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-450/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-450/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-450/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-450/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-900/ (stored 0%)
#   adding: content/outputs/checkpoint-900/optimizer.pt (deflated 12%)
#   adding: content/outputs/checkpoint-900/scheduler.pt (deflated 56%)
#   adding: content/outputs/checkpoint-900/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-900/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-900/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-900/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-900/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-900/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-900/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-900/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-900/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-200/ (stored 0%)
#   adding: content/outputs/checkpoint-200/optimizer.pt (deflated 12%)
#   adding: content/outputs/checkpoint-200/scheduler.pt (deflated 56%)
#   adding: content/outputs/checkpoint-200/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-200/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-200/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-200/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-200/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-200/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-200/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-200/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-200/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-50/ (stored 0%)
#   adding: content/outputs/checkpoint-50/optimizer.pt (deflated 11%)
#   adding: content/outputs/checkpoint-50/scheduler.pt (deflated 56%)
#   adding: content/outputs/checkpoint-50/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-50/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-50/trainer_state.json (deflated 80%)
#   adding: content/outputs/checkpoint-50/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-50/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-50/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-50/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-50/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-50/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-800/ (stored 0%)
#   adding: content/outputs/checkpoint-800/optimizer.pt (deflated 13%)
#   adding: content/outputs/checkpoint-800/scheduler.pt (deflated 55%)
#   adding: content/outputs/checkpoint-800/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-800/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-800/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-800/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-800/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-800/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-800/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-800/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-800/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-600/ (stored 0%)
#   adding: content/outputs/checkpoint-600/optimizer.pt (deflated 12%)
#   adding: content/outputs/checkpoint-600/scheduler.pt (deflated 56%)
#   adding: content/outputs/checkpoint-600/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-600/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-600/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-600/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-600/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-600/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-600/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-600/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-600/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-500/ (stored 0%)
#   adding: content/outputs/checkpoint-500/optimizer.pt (deflated 12%)
#   adding: content/outputs/checkpoint-500/scheduler.pt (deflated 55%)
#   adding: content/outputs/checkpoint-500/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-500/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-500/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-500/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-500/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-500/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-500/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-500/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-500/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-843/ (stored 0%)
#   adding: content/outputs/checkpoint-843/optimizer.pt (deflated 13%)
#   adding: content/outputs/checkpoint-843/scheduler.pt (deflated 56%)
#   adding: content/outputs/checkpoint-843/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-843/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-843/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-843/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-843/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-843/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-843/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-843/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-843/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-350/ (stored 0%)
#   adding: content/outputs/checkpoint-350/optimizer.pt (deflated 12%)
#   adding: content/outputs/checkpoint-350/scheduler.pt (deflated 56%)
#   adding: content/outputs/checkpoint-350/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-350/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-350/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-350/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-350/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-350/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-350/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-350/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-350/adapter_model.safetensors (deflated 7%)
#   adding: content/outputs/checkpoint-650/ (stored 0%)
#   adding: content/outputs/checkpoint-650/optimizer.pt (deflated 12%)
#   adding: content/outputs/checkpoint-650/scheduler.pt (deflated 56%)
#   adding: content/outputs/checkpoint-650/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-650/README.md (deflated 66%)
#   adding: content/outputs/checkpoint-650/trainer_state.json (deflated 81%)
#   adding: content/outputs/checkpoint-650/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-650/training_args.bin (deflated 51%)
#   adding: content/outputs/checkpoint-650/rng_state.pth (deflated 25%)
#   adding: content/outputs/checkpoint-650/adapter_config.json (deflated 54%)
#   adding: content/outputs/checkpoint-650/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-650/adapter_model.safetensors (deflated 7%)
